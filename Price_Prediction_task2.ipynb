# %%
import pandas as pd
df=pd.read_csv("/home/mansi/Desktop/internship/cognoRise_internship_task/task2/data.csv")
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()

df["city"]=l.fit_transform(df["city"])
df["city"]
# Out:
# 0       36
# 1       35
# 2       18
# 3        3
# 4       31
#         ..
# 4595    35
# 4596     3
# 4597    32
# 4598    35
# 4599     9
# Name: city, Length: 4600, dtype: int64

# %%
x=(df[["sqft_living","bedrooms","city"]])
x
# Out:
#       sqft_living  bedrooms  city
# 0            1340       3.0    36
# 1            3650       5.0    35
# 2            1930       3.0    18
# 3            2000       3.0     3
# 4            1940       4.0    31
# ...           ...       ...   ...
# 4595         1510       3.0    35
# 4596         1460       3.0     3
# 4597         3010       3.0    32
# 4598         2090       4.0    35
# 4599         1490       3.0     9
#
# [4600 rows x 3 columns]

# %%
y=df.iloc[:,1:2]
y
# Out:
#              price
# 0     3.130000e+05
# 1     2.384000e+06
# 2     3.420000e+05
# 3     4.200000e+05
# 4     5.500000e+05
# ...            ...
# 4595  3.081667e+05
# 4596  5.343333e+05
# 4597  4.169042e+05
# 4598  2.034000e+05
# 4599  2.206000e+05
#
# [4600 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=3)

print("length of x_train data is ",len(x_train))
print("length of y_train data is ",len(y_train))
# Out:
# length of x_train data is  3680
# length of y_train data is  3680

# %%
x_train
# Out:
#       sqft_living  bedrooms  city
# 676          1660       3.0    35
# 2578         1120       2.0    35
# 1157         1470       3.0    35
# 4159         2610       4.0    35
# 1757         2390       3.0    35
# ...           ...       ...   ...
# 789          3120       4.0    35
# 968          1320       4.0    35
# 1667         1380       2.0    35
# 3321         2490       4.0    31
# 1688         1840       3.0    35
#
# [3680 rows x 3 columns]

# %%
y_train
# Out:
#          price
# 676   458000.0
# 2578  524000.0
# 1157  432000.0
# 4159  674600.0
# 1757  689800.0
# ...        ...
# 789   799000.0
# 968   387500.0
# 1667  285000.0
# 3321  725000.0
# 1688  686000.0
#
# [3680 rows x 1 columns]

# %%
#1.linear Regression
from sklearn.linear_model import LinearRegression
l=LinearRegression()
l

model=l.fit(x_train,y_train)
model

pred=l.predict(x_test)
pred
# Out:
# array([[ 694426.31821306],
#        [ 601564.42166182],
#        [ 629222.77514316],
#        [ 580067.26264024],
#        [ 532268.26589809],
#        [ 971236.08924717],
#        [ 634641.56902388],
#        [ 373866.18980448],
#        [ 635383.96960291],
#        [ 597674.40226534],
#        [ 591031.01260234],
#        [ 475192.91364927],
#        [ 437112.14602218],
#        [ 250242.29428062],
#        [ 653192.17399071],
#        [ 666323.98507682],
#        [ 432353.56384599],
#        [ 727570.48716268],
#        [ 862301.58533288],
#        [ 250242.29428062],
#        [ 966255.51724353],
#        [ 520919.67689419],
#        [ 452670.10041145],
#        [ 561449.63608585],
#        [ 630254.18713721],
#        [ 456709.33027   ],
#        [ 515173.65605011],
#        [ 191999.95832796],
#        [ 352413.00410906],
#        [ 348146.02664524],
#        [ 700061.34414341],
#        [ 474301.30260816],
#        [ 305693.04441842],
#        [ 508032.90389693],
# ...

# %%
from sklearn.metrics import r2_score,mean_squared_error
print(r2_score(y_test,pred))
print(mean_squared_error(y_test,pred))
# Out:
# 0.033778839666712246
# 827331022077.1962

# %%
input=[[1700,4,33]]
prediction=model.predict(input)
prediction
# Out:
# /home/mansi/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[403663.7983706]])

# %%
#plot the result
import matplotlib.pyplot as plt
plt.scatter(y_test,pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()

# %%
#2.random forest regression
from sklearn.ensemble import RandomForestRegressor
r=RandomForestRegressor(max_depth=4)

model=r.fit(x_train,y_train)
model

pred=model.predict(x_test)
pred
# Out:
# /home/mansi/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# array([ 723931.52655367,  667031.47712826,  665647.62276228,
#         682329.24252243,  539981.36403196,  947502.86666418,
#         622287.44042526,  370890.10896994,  665647.62276228,
#         573078.53656678,  512413.33479722,  488359.42478187,
#         405143.58637718,  361585.04078424,  631842.08246474,
#         704566.7674664 ,  397939.63611226,  767790.60041085,
#         782361.26041131,  361585.04078424,  937189.96295139,
#         486965.30166121,  370890.10896994,  497980.600879  ,
#         560565.33624414,  488359.42478187,  488359.42478187,
#         277358.12660345,  370890.10896994,  331312.96700783,
#         691754.6435619 ,  372863.62680192,  361585.04078424,
# ...

# %%
print("r2 score ",r2_score(y_test,pred))
print("mean_squared error ",mean_squared_error(y_test,pred))
# Out:
# r2 score  0.028909155471872228
# mean_squared error  831500710102.5758

# %%
#plot the result
import matplotlib.pyplot as plt
plt.scatter(y_test,pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()

# %%
#3.decision tree regression
from sklearn.tree import DecisionTreeRegressor
d=DecisionTreeRegressor(max_depth=3)
d

model=d.fit(x_train,y_train)
model

pred=model.predict(x_test)
pred
# Out:
# array([ 845958.87293383,  688088.09568709,  688088.09568709,
#         688088.09568709,  528564.16164211,  845958.87293383,
#         688088.09568709,  415507.83329348,  688088.09568709,
#         688088.09568709,  415507.83329348,  415507.83329348,
#         415507.83329348,  306862.47604459,  688088.09568709,
#         688088.09568709,  415507.83329348,  845958.87293383,
#         845958.87293383,  306862.47604459,  845958.87293383,
#         415507.83329348,  415507.83329348,  415507.83329348,
#         528564.16164211,  415507.83329348,  415507.83329348,
#         306862.47604459,  415507.83329348,  415507.83329348,
#         845958.87293383,  415507.83329348,  306862.47604459,
#         528564.16164211,  415507.83329348,  415507.83329348,
#         688088.09568709,  688088.09568709,  415507.83329348,
#         415507.83329348,  415507.83329348,  306862.47604459,
#         688088.09568709,  528564.16164211,  415507.83329348,
# ...

# %%
print("r2 score ",r2_score(y_test,pred))
print("mean_squared error ",mean_squared_error(y_test,pred))
# Out:
# r2 score  0.020643084166399706
# mean_squared error  838578569191.6488

# %%
#4.gradient boosting regression
from sklearn.ensemble import GradientBoostingRegressor
g=GradientBoostingRegressor( max_depth=2, learning_rate=0.1)
g

model=g.fit(x_train,y_train)
model

pred=model.predict(x_test)
pred
# Out:
# /home/mansi/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([ 842781.95957151,  708543.48049644,  723465.88140163,
#         689949.64666242,  485977.8876165 ,  998893.59333138,
#         546771.36705676,  316767.13010116,  723465.88140163,
#         481113.92408888,  449446.12950725,  536859.98272135,
#         391242.14361712,  352817.66499887,  558192.17139543,
#         729056.97273542,  447625.0839746 ,  528367.53876138,
#         746022.64007188,  352817.66499887,  813423.95293115,
#         409871.23893794,  350902.83909049,  567686.96309626,
#         543521.22997942,  536859.98272135,  536859.98272135,
#         332238.42480733,  546928.22634263,  351518.52492473,
#         582815.55568464,  350902.83909049,  377641.63685374,
# ...

# %%
print("r2 score ",r2_score(y_test,pred))
print("mean_squared error ",mean_squared_error(y_test,pred))
# Out:
# r2 score  0.029986290314461095
# mean_squared error  830578408763.2773

# %%
#plot the result
import matplotlib.pyplot as plt
plt.scatter(y_test,pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
